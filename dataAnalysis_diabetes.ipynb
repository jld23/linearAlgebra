# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_profiling

from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_roc_curve

# %%
diabetes = pd.read_csv('./data/diabetes.csv')
diabetes.shape
# Out:
# (768, 9)

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Profileing Report

# %%
pandas_profiling.ProfileReport(diabetes)
# Out:
# variables: 100%|██████████| 9/9 [00:00<00:00, 19.46it/s]
# correlations [phi_k]:  50%|█████     | 3/6 [00:00<00:00,  5.78it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-04e3f4497a1e> in <module>
# ----> 1 pandas_profiling.ProfileReport(diabetes)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas_profiling/__init__.py in __init__(self, df, minimal, config_file, **kwargs)
#      61
#      62         # Get dataset statistics
# ---> 63         description_set = describe_df(df)
#      64
#      65         # Build report structure
#
# ~/miniconda3/lib/python3.7/site-packages/pandas_profiling/model/describe.py in describe(df)
#     620
#     621     # Get correlations
# --> 622     correlations = calculate_correlations(df, variables)
#     623
#     624     # Scatter matrix
#
# ~/miniconda3/lib/python3.7/site-packages/pandas_profiling/model/correlations.py in calculate_correlations(df, variables)
#     216                             try:
#     217                                 correlations["phi_k"] = df[selcols].phik_matrix(
# --> 218                                     interval_cols=intcols
#     219                                 )
#     220
#
# ~/miniconda3/lib/python3.7/site-packages/phik/phik.py in phik_matrix(df, interval_cols, bins, quantile, noise_correction, dropna, drop_underflow, drop_overflow)
#     215     data_binned, binning_dict = bin_data(df_clean, cols=interval_cols_clean, bins=bins, quantile=quantile, retbins=True)
#     216     return phik_from_rebinned_df(data_binned, noise_correction, dropna=dropna, drop_underflow=drop_underflow,
# --> 217                                  drop_overflow=drop_overflow)
#     218
#     219
#
# ~/miniconda3/lib/python3.7/site-packages/phik/phik.py in phik_from_rebinned_df(data_binned, noise_correction, dropna, drop_underflow, drop_overflow)
#     145
#     146     phik_list = Parallel(n_jobs=NCORES)(delayed(_calc_phik)(co, data_binned[list(co)], noise_correction)
# --> 147                                         for co in itertools.combinations_with_replacement(data_binned.columns.values, 2))
#     148
#     149     phik_overview = create_correlation_overview_table(dict(phik_list))
#
# ~/miniconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     919
#     920                 # If the backend allows it, cancel or kill remaining running
# --> 921                 # tasks without waiting for the results as we will raise
#     922                 # the exception we got back to the caller instead of returning
#     923                 # any result.
#
# ~/miniconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757             # grow. To ensure correct results ordering, .insert is
#     758             # used (rather than .append) in the following line
# --> 759             self._jobs.insert(job_idx, job)
#     760
#     761     def dispatch_next(self):
#
# ~/miniconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714                     'The backend class {!r} does not support timeout. '
#     715                     "You have set 'timeout={}' in Parallel but "
# --> 716                     "the 'timeout' parameter will not be used.".format(
#     717                         self._backend.__class__.__name__,
#     718                         self.timeout))
#
# ~/miniconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     508         """Build a process executor and return the number of workers"""
#     509         n_jobs = self.effective_n_jobs(n_jobs)
# --> 510         if n_jobs == 1:
#     511             raise FallbackToBackend(
#     512                 SequentialBackend(nesting_level=self.nesting_level))
#
# ~/miniconda3/lib/python3.7/site-packages/joblib/externals/loky/reusable_executor.py in submit(self, fn, *args, **kwargs)
#     149                  env=None):
#     150         super(_ReusablePoolExecutor, self).__init__(
# --> 151             max_workers=max_workers, context=context, timeout=timeout,
#     152             job_reducers=job_reducers, result_reducers=result_reducers,
#     153             initializer=initializer, initargs=initargs, env=env)
#
# ~/miniconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py in submit(self, fn, *args, **kwargs)
#    1040
#    1041             self._pending_work_items[self._queue_count] = w
# -> 1042             self._work_ids.put(self._queue_count)
#    1043             self._queue_count += 1
#    1044             # Wake up queue management thread
#
# ~/miniconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py in _ensure_executor_running(self)
#    1014         mp.util.debug('Adjust process count : {}'.format(self._processes))
#    1015
# -> 1016     def _ensure_executor_running(self):
#    1017         """ensures all workers and management thread are running
#    1018         """
#
# ~/miniconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py in _adjust_process_count(self)
#    1005                 # Try to spawn the process with some environment variable to
#    1006                 # overwrite but it only works with the loky context for now.
# -> 1007                 p = self._context.Process(target=_process_worker, args=args,
#    1008                                           env=self._env)
#    1009             except TypeError:
#
# ~/miniconda3/lib/python3.7/multiprocessing/process.py in start(self)
#     110                'daemonic processes are not allowed to have children'
#     111         _cleanup()
# --> 112         self._popen = self._Popen(self)
#     113         self._sentinel = self._popen.sentinel
#     114         # Avoid a refcycle if the target function holds an indirect
#
# ~/miniconda3/lib/python3.7/site-packages/joblib/externals/loky/backend/process.py in _Popen(process_obj)
#      35         if sys.platform == "win32":
#      36             from .popen_loky_win32 import Popen
# ---> 37         else:
#      38             from .popen_loky_posix import Popen
#      39         return Popen(process_obj)
#
# ~/miniconda3/lib/python3.7/site-packages/joblib/externals/loky/backend/popen_loky_posix.py in __init__(self, process_obj)
#      50             self.returncode = None
#      51             self._fds = []
# ---> 52             self._launch(process_obj)
#      53
#      54         if sys.version_info < (3, 4):
#
# ~/miniconda3/lib/python3.7/site-packages/joblib/externals/loky/backend/popen_loky_posix.py in _launch(self, process_obj)
#     151                 self._fds.extend([child_r, child_w, tracker_fd])
#     152                 from .fork_exec import fork_exec
# --> 153                 pid = fork_exec(cmd_python, self._fds, env=process_obj.env)
#     154                 util.debug("launched python with pid {} and cmd:\n{}"
#     155                            .format(pid, cmd_python))
#
# AttributeError: 'LokyProcess' object has no attribute 'env'

# %% [markdown]
# # Univariate Statistics

# %%
df = diabetes

# %% [markdown]
# ## Variable Types

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %%
preg_proportion = np.array(df['Pregnancies'].value_counts())
preg_month = np.array(df['Pregnancies'].value_counts().index)
preg_proportion_perc = np.array(np.round(preg_proportion/sum(preg_proportion),3)*100,dtype=int)

preg = pd.DataFrame({'month':preg_month,'count_of_preg_prop':preg_proportion,'percentage_proportion':preg_proportion_perc})
preg.set_index(['month'],inplace=True)
preg.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d466c0d5ca7f> in <module>
# ----> 1 preg_proportion = np.array(df['Pregnancies'].value_counts())
#       2 preg_month = np.array(df['Pregnancies'].value_counts().index)
#       3 preg_proportion_perc = np.array(np.round(preg_proportion/sum(preg_proportion),3)*100,dtype=int)
#       4
#       5 preg = pd.DataFrame({'month':preg_month,'count_of_preg_prop':preg_proportion,'percentage_proportion':preg_proportion_perc})
#
# NameError: name 'np' is not defined

# %%
sns.set_style("darkgrid")
sns.FacetGrid(df, hue="Outcome", )\
    .map(plt.scatter, "Pregnancies", "Outcome")\
    .add_legend()
plt.show()

# %%
diabetes.hist(figsize=(20,20));

# %%
sns.regplot(x=diabetes['Glucose'], y=diabetes['Insulin']);

# %%
sns.lmplot(x="Glucose", y="Insulin", hue="Outcome", data=diabetes);

# %%
g = sns.jointplot(x="Glucose", y="Insulin", data=diabetes, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$Glucose$", "$Insulin$");

# %%
sns.heatmap(diabetes.corr(),square=True);

# %%
sns.clustermap(diabetes, z_score=0, cmap="vlag");
